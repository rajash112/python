# %% [markdown]
# **Creating Series from Array**

# %%
import pandas as pd
import numpy as np
info = np.array(['a','s','h','i','s','h'])
a = pd.Series(info)
print(a)
# Out:
# 0    a
# 1    s
# 2    h
# 3    i
# 4    s
# 5    h
# dtype: object

# %% [markdown]
# **creating a dataframe using list:**

# %%
import pandas as pd
#a list of strings
x =['patna','bihar']
# calling DataFrame constructor on list
df=pd.DataFrame(x)
print(df)
# Out:
#        0
# 0  patna
# 1  bihar

# %%
import pandas as pd
import numpy as np
a=pd.Series(['html','linux','maths',np.nan])
a.map({'html':'Core'})
# Out:
# 0    Core
# 1     NaN
# 2     NaN
# 3     NaN
# dtype: object

# %%
import pandas as pd
import numpy as np
a=pd.Series(['html','linux','maths',np.nan])
a.map({'html':'core'})
a.map('I like{maths}'.formate,na_action='ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7e36f3175a28> in <cell line: 5>()
#       3 a=pd.Series(['html','linux','maths',np.nan])
#       4 a.map({'html':'core'})
# ----> 5 a.map('I like{maths}'.formate,na_action='ignore')
#
# AttributeError: 'str' object has no attribute 'formate'

# %%
s=pd.Series(["ham","tum","woh"],
name="vals")
s.to_frame()
# Out:
#   vals
# 0  ham
# 1  tum
# 2  woh
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('vals').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
import pandas as pd
import numpy as np
emp=['Ashish','Kajal','Gurlez','raj']
id=[112,204,542,234]
emp_Series=pd.Series(emp)
id_Series=pd.Series(id)
frame={'Emp':emp_Series,'ID':id_Series}
result=pd.DataFrame(frame)
print(result)
# Out:
#       Emp   ID
# 0  Ashish  112
# 1   Kajal  204
# 2  Gurlez  542
# 3     raj  234

# %% [markdown]
# **end of exercise 1**

# %%
# importing the pandas library
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# importing the pandas library
import pandas as pd
# a list of strings
x=['patna','bihar']
# calling dataFrame constructor on list
df=pd.DataFrame(x)
print(df)
# Out:
#        0
# 0  patna
# 1  bihar

# %%
# importing the pandas library
import pandas as pd
info={'ID':[1001,1002,1003],'department':['B.Tech','M.Tech','B.Sc']}
df=pd.DataFrame(info)
print(df)
# Out:
#      ID department
# 0  1001     B.Tech
# 1  1002     M.Tech
# 2  1003       B.Sc

# %% [markdown]
# create a dataframe from dict of series

# %%
# importing the pandas library
import pandas as pd
info={'one':pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f']),
'two':pd.Series([1,2,3,4,5,6,7,8],index=['a','b','c','d','e','f','g','h'])}
d1=pd.DataFrame(info)
print(d1)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  4.0    4
# e  5.0    5
# f  6.0    6
# g  NaN    7
# h  NaN    8

# %%
# importing the pandas library
import pandas as pd
info={'one':pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f']),
'two':pd.Series([1,2,3,4,5,6,7,8],index=['a','b','c','d','e','f','g','h'])}
d1=pd.DataFrame(info)
print(d1['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    6.0
# g    NaN
# h    NaN
# Name: one, dtype: float64

# %%
# importing the pandas library
import pandas as pd
info={'one':pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f']),
'two':pd.Series([1,2,3,4,5,6,7,8],index=['a','b','c','d','e','f','g','h'])}
d1=pd.DataFrame(info)
# add a new column using existing DataFrame object
print("add new column by passing series")
d1['three']=pd.Series([100,200,300],index=['a','b','c'])
print(d1)
print("add new column using existing DataFrame columns")
d1['four']=d1['one']+d1['three']
print(d1)
# Out:
# add new column by passing series
#    one  two  three
# a  1.0    1  100.0
# b  2.0    2  200.0
# c  3.0    3  300.0
# d  4.0    4    NaN
# e  5.0    5    NaN
# f  6.0    6    NaN
# g  NaN    7    NaN
# h  NaN    8    NaN
# add new column using existing DataFrame columns
#    one  two  three   four
# a  1.0    1  100.0  101.0
# b  2.0    2  200.0  202.0
# c  3.0    3  300.0  303.0
# d  4.0    4    NaN    NaN
# e  5.0    5    NaN    NaN
# f  6.0    6    NaN    NaN
# g  NaN    7    NaN    NaN
# h  NaN    8    NaN    NaN

# %% [markdown]
# **column deletion**

# %%
#importing the pandas library
import pandas as pd
info={'one':pd.Series([1,2],index=['a','b'],
'two':pd.Series([1,2,3],index=['a','b','c'] )}
df=pd.DataFrame(info)
print("The DataFrame")
